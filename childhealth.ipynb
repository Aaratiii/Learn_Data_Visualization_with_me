# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
#Load the data

child_filepath = r"C:\Users\user\Desktop\cre\Data-Visualization\childhealth.csv"

# %%
child_data = pd.read_csv(child_filepath)

# %%
child_data.head()
# Out:
#    SchoolYear NameHospital     Sex  EpiUnderweight  EpiHealthyWeight  \
# 0        2001      Borders  Female               2               334
# 1        2001      Borders    Male               5               301
# 2        2001      Lothian  Female              12               728
# 3        2001      Lothian    Male              17               681
# 4        2001         Fife  Female              17              1361
#
#    EpiOverweight  EpiObese  EpiOverweightAndObese  ValidCounts  UnvalidCounts  \
# 0             54        28                     82          418             82
# 1             63        42                    105          411            105
# 2            133       106                    239          979            239
# 3            124       114                    238          936            238
# 4            231       155                    386         1764            386
#
#    TotalCounts
# 0          500
# 1          516
# 2         1218
# ...

# %%
child_data.tail()
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 511        2023                    Tayside    Male              15
# 512        2023  Greater Glasgow and Clyde  Female              34
# 513        2023  Greater Glasgow and Clyde    Male              89
# 514        2023                Lanarkshire  Female              14
# 515        2023                Lanarkshire    Male              31
#
#      EpiHealthyWeight  EpiOverweight  EpiObese  EpiOverweightAndObese  \
# 511              1201            216       178                    394
# 512              4097            595       561                   1156
# 513              4152            615       641                   1256
# 514              2255            381       330                    711
# 515              2280            348       381                    729
#
#      ValidCounts  UnvalidCounts  TotalCounts
# 511         1610            394         2004
# 512         5287           1156         6443
# ...

# %%
child_data.tail(30)
# Out:
#      SchoolYear               NameHospital     Sex  EpiUnderweight  \
# 486        2022                Lanarkshire  Female              14
# 487        2022                Lanarkshire    Male              43
# 488        2023         Ayrshire and Arran  Female              10
# 489        2023         Ayrshire and Arran    Male              20
# 490        2023                    Borders  Female               0
# 491        2023                    Borders    Male               5
# 492        2023      Dumfries and Galloway  Female               7
# 493        2023      Dumfries and Galloway    Male               8
# 494        2023               Forth Valley  Female              20
# 495        2023               Forth Valley    Male              54
# 496        2023                   Grampian  Female              12
# 497        2023                   Grampian    Male              22
# 498        2023                   Highland  Female               4
# ...

# %%
#Let me plot the data now

plt.Figure(figsize=(16,10))
sns.lineplot(data = child_data)
# Out:
# <Axes: >

# %%
#Let me plot the data now

plt.Figure(figsize=(16,10))
sns.barplot(data = child_data)
# Out:
# <Axes: >

# %%
#Let me plot the data now
plt.title = ("Child health")
plt.Figure(figsize=(16,10))
sns.histplot(data = child_data)
# Out:
# <Axes: ylabel='Count'>
